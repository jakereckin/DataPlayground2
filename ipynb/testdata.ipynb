# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt
from mlxtend.frequent_patterns import apriori, association_rules

# %%
basketball_data = pd.read_csv(r'C:\Users\Jake\Documents\GitHub\FunAnalyticalStuff\hs_wbb_model\Basketball_Final_Stats.csv')
basketball_data_drop_extra = basketball_data.drop(columns = ['Game_ID',  'Total Points_Allowed', 'Total Points', 'Points_Allowed', 'Efficient Points Score', 'Raw EOP', 'Efficient Points Score_Allowed', 'Raw EOP_Allowed', 'Offensive_Efficieny_Difference', 'Fouls', 'Technical Fouls', 'Fouls_Allowed',
       'Technical Fouls_Allowed', 'Blocks', 'Blocks_Allowed'])

# %%
team_wins_loss = basketball_data_drop_extra.groupby(by = ['Team', 'Win'], as_index = False).mean()
team_wins_loss_size = basketball_data_drop_extra.groupby(by = ['Team', 'Win'], as_index = False).size()
team_wins_loss_size
# Out:
#                             Team  Win  size
# 0                     Abbotsford    0     6
# 1    Abundant Life/Saint Ambrose    0     4
# 2      Abundant Life/St. Ambrose    0     4
# 3      Abundant Life/St. Ambrose    1     4
# 4                         Albany    1     5
# ..                           ...  ...   ...
# 502               Wonewoc-Center    1     1
# 503                  Wrightstown    0     2
# 504                  Wrightstown    1     8
# 505                       Xavier    0     4
# 506                       Xavier    1     2
#
# [507 rows x 3 columns]

# %%
flights = pd.read_csv('flights.csv')
flights_aa = flights[flights['AIRLINE'] == 'AA']
flights_aa
# Out:
# c:\Users\Jake\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# c:\Users\Jake\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 1        2015      1    1            4      AA           2336      N3KUAA
# 3        2015      1    1            4      AA            258      N3HYAA
# 8        2015      1    1            4      AA           1112      N3LAAA
# 11       2015      1    1            4      AA           1674      N853AA
# ...

# %%
flights_aa.to_csv('aa_flights.bz2', index = False, compression = 'bz2')
# Out:
# c:\Users\Jake\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
test = pd.read_csv('aa_flights.bz2', compression = 'bz2')
test
# Out:
# c:\Users\Jake\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# c:\Users\Jake\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0       2015      1    1            4      AA           2336      N3KUAA
# 1       2015      1    1            4      AA            258      N3HYAA
# 2       2015      1    1            4      AA           1112      N3LAAA
# 3       2015      1    1            4      AA           1674      N853AA
# ...

# %%
my_excel_file = r'C:\Users\Jake\Documents\Grad School\DS 735\VTL Strength Index - External Indicator Data - 12JULY2022.xlsx'
data = pd.read_excel(my_excel_file).drop(columns = ['Date'])
data
# Out:
# c:\Users\Jake\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     VTL Strength   LMI   PMI  \
# 0           63.7  70.0  59.3
# 1           71.2  69.2  59.1
# 2           74.7  69.2  60.7
# 3           69.3  75.7  59.3
# 4           68.1  75.7  57.9
# 5           77.9  72.5  58.7
# 6           74.9  72.5  60.0
# 7           70.0  70.5  58.4
# 8           52.3  70.2  60.8
# 9           51.9  70.2  59.5
# 10          54.5  70.2  57.5
# 11          43.5  63.5  58.8
# 12          26.0  63.5  54.3
# 13          31.9  62.5  56.6
# 14          10.5  61.0  54.1
# 15           4.0  59.0  54.6
# 16           1.5  57.0  53.4
# 17          14.5  55.5  52.3
# 18           7.0  57.0  51.6
# ...

# %%
def get_redundanent_pairs(df):
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i + 1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_correlations(df):
    au_corr = df.corr().unstack()
    labels_to_drop = get_redundanent_pairs(df)
    au_corr_final = au_corr.drop(labels = labels_to_drop).sort_values(ascending = True)
    return au_corr_final
# Out:
# c:\Users\Jake\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
new_frame = get_correlations(data)
#new_frame_strength = new_frame[(new_frame['Feature 1'] == 'VTL Strength') | (new_frame['Feature 2'] == 'VTL Strength')]
#new_frame_strength
my_data = new_frame['VTL Strength']
# Out:
# c:\Users\Jake\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from matplotlib.colors import TwoSlopeNorm
fig, ax = plt.subplots(figsize = (15, 10))
norm = TwoSlopeNorm(vmin = -1, vcenter = 0, vmax = 1)
colors = [plt.cm.RdYlBu_r(norm(c)) for c in my_data.values]
my_data.plot.barh(color = colors)
# Out:
# c:\Users\Jake\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <AxesSubplot:>

# %%
import seaborn as sns
sns.relplot(x = data['VTL Strength'], y = data['Transportation Employment'])
# Out:
# c:\Users\Jake\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
sns.relplot(x = data['VTL Strength'], y = data['Morgan Stanley Freight Index'])
# Out:
# c:\Users\Jake\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
